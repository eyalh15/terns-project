# %%
import os

dir = '/content/drive/MyDrive/tern_project/Eyal/LabelsDistributionInFlags/'

os.chdir(dir)
print(os.getcwd())
# Out:
# /content/drive/MyDrive/tern_project/Eyal/LabelsDistributionInFlags

# %%
# !python labels_distributions_creator.py -d './../TernsTags/images_to_tag(Rotem)/02_06_1000' './../TernsTags/images_to_tag(Rotem)/03_07_0530'
# Out:
# Label probabilities have been calculated and saved to label_probabilities.json
