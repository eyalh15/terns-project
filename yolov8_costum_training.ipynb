# %% [markdown]
# ### Install the Ultralytics library which includes implementations of YOLO models

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.5/701.5 kB 5.7 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.4 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Train Pre-trained Yolo model with terns annotated data.

# %%
# !yolo task=detect mode=train model=yolov8s.pt data='/content/drive/MyDrive/tern_project/Eyal/YoloDetector/TrainedVersions/Terns Detection 3.0.v4i.yolov8/data.yaml' epochs=15 imgsz=640 batch=8 project='/content/drive/MyDrive/tern_project/Eyal/YoloDetector/TrainedVersions/Terns Detection 3.0.v4i.yolov8/' name=terns-detection
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 210MB/s]
# Ultralytics YOLOv8.1.4 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import os

root_directory = "/content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images"
os.chdir(root_directory)

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/tern_project/Eyal/YoloDetector/YoloModel/Terns Detection 2.0.v1i.yolov8/best.pt' conf=0.2 source="/content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images"
# Out:
# Ultralytics YOLOv8.1.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11129454 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/83 /content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images/flag1_0_atlitcam191.stream_2023_07_21_15_00_00.jpg: 384x640 1 2, 19 3s, 111.1ms
# image 2/83 /content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images/flag1_10_atlitcam191.stream_2023_07_21_15_00_00.jpg: 384x640 25 3s, 10.8ms
# image 3/83 /content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images/flag1_11_atlitcam191.stream_2023_07_21_15_00_00.jpg: 384x640 18 3s, 10.7ms
# image 4/83 /content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images/flag1_12_atlitcam191.stream_2023_07_21_15_00_00.jpg: 384x640 20 3s, 10.7ms
# image 5/83 /content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images/flag1_13_atlitcam191.stream_2023_07_21_15_00_00.jpg: 384x640 19 3s, 10.7ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/tern_project/Eyal/YoloDetector/YoloModel/Terns Detection 2.0.v2i.yolov8/best.pt' conf=0.2 source="/content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images"
# Out:
# Ultralytics YOLOv8.1.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11129841 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/83 /content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images/flag1_0_atlitcam191.stream_2023_07_21_15_00_00.jpg: 384x640 3 2s, 17 3s, 107.0ms
# image 2/83 /content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images/flag1_10_atlitcam191.stream_2023_07_21_15_00_00.jpg: 384x640 3 2s, 18 3s, 10.7ms
# image 3/83 /content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images/flag1_11_atlitcam191.stream_2023_07_21_15_00_00.jpg: 384x640 2 2s, 16 3s, 1 4, 10.7ms
# image 4/83 /content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images/flag1_12_atlitcam191.stream_2023_07_21_15_00_00.jpg: 384x640 1 2, 16 3s, 1 4, 10.7ms
# image 5/83 /content/drive/MyDrive/tern_project/Eyal/YoloDetector/test_images/flag1_13_atlitcam191.stream_2023_07_21_15_00_00.jpg: 384x640 2 2s, 17 3s, 10.7ms
# ...
